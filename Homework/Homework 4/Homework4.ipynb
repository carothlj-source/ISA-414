# %%
import hw4_module

# %%
df = hw4_module.ip2address(["165.70.141.165", 
                        "93.215.167.191", 
                        "197.177.61.197", 
                        "206.236.177.182", 
                        "5.77.63.24", 
                        "158.227.31.151",                             
                        "82.233.65.66", 
                        "63.123.244.194"])
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/pandas/core/computation/expressions.py:23: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = df[["ip", "country_name", "city", "latitude", "longitude"]]

print(df)

df.to_csv("hw4_updated.csv", index=False)
# Out:
#                 ip    country_name        city  latitude   longitude
# 0   165.70.141.165   United States     Seattle  47.55379  -122.30346
# 1   93.215.167.191         Germany       Essen  51.45562     7.01045
# 2   197.177.61.197           Kenya     Nairobi  -1.25917    36.78583
# 3  206.236.177.182   United States  Washington  38.90701   -77.05270
# 4       5.77.63.24  United Kingdom      London  51.50967    -0.09925
# 5   158.227.31.151           Spain      Lejona  43.33450    -2.98593
# 6     82.233.65.66          France       Paris  48.87135     2.32115
# 7   63.123.244.194   United States     Trenton  40.21788   -74.75940
