# %%
import random

# %%
price = 25
c = len("carothers")
days = c * 5

# %%
for x in range (days):
    print(price)
    e = random.gauss(0, 1)
    price = price + e
# Out:
# 25
# 23.618820592248653
# 21.878404100794896
# 23.53997561851472
# 23.262165972548402
# 23.407035657749987
# 23.8073776094702
# 24.149905668009698
# 23.31453555707167
# 23.2534427585644
# 24.694165172405366
# 24.31171119255794
# 23.36221469721415
# 22.142997370664656
# 22.980568369216083
# 23.47255730857274
# 24.844037656519703
# 25.2137714480482
# 27.155330929615175
# 26.38951880881932
# 26.421548688664103
# 27.899000543928214
# 27.917968857889996
# 27.47474112182652
# 29.05664878319758
# 29.484594969538144
# 28.249306361520915
# 28.448514941805424
# 28.077747060187974
# 27.731188277528034
# 30.080473980137192
# 30.472305083076986
# 32.0521844332287
# 32.34065199688921
# 29.95898181238273
# 28.738085540326047
# 29.434545816844604
# 31.07885796228455
# 29.342969282311625
# 29.905090223389664
# 28.901888773235317
# 27.62847251489197
# 27.19303992639941
# 27.602869617756266
# 26.700893319969442
