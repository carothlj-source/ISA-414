# %% [markdown]
# # The First Jupyter Notebook
# Markdown Cell

# %% [markdown]
# 1. Define variables
# 2. Print them on screen

# %%
#define a variable named x
x = 1
#print the value on the screen
print(x)
# Out:
# 1

# %%
y = 10
print(y)
# Out:
# 10

# %%
print(x)
# Out:
# 1

# %% [markdown]
# # Perform more complex computation

# %%
y = 10 * 8 + 10 -8 **2
print(y)
# Out:
# 26

# %% [markdown]
# # Creating a Table in Markdown
#
# | Syntax | Description |
# | ----------- | ----------- |
# | Header | Title |
# | Paragraph | Text |

# %% [markdown]
# # This is my *first* **notebook**

# %%
x = 1

# %% [markdown]
# The code `x=1` assigns the value 1 to `x`
#
# And here is an image of ISA Faculty:
# Link: [ISA
# Professors](https://miamioh.edu/fsb/directory/?up=/query/all/all/Information%20Systems%20--%20Analytics/all)
# ![ISA Professors](https://www.fsb.miamioh.edu/fsb/directory/pic/xur29.jpg)
